# %%
import numpy as np
import pandas as pd
import os

# %%
#  give \\ or /
pd.read_csv("C:\\Users\\Piyush Nayak\\OneDrive\\Desktop\\PYTHON\\Acmegrade\\PYTHON LEC\\Jan 24 ML Day 8\\DemographicData.csv")
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
pd.read_csv("C:/Users/Piyush Nayak/OneDrive/Desktop/PYTHON/Acmegrade/PYTHON LEC/Jan 24 ML Day 8/DemographicData.csv")
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Piyush Nayak\\PYTHON PRAC'

# %%
pd.read_csv("C:\\Users\\Piyush Nayak\\OneDrive\\Desktop\\PYTHON\\Acmegrade\\PYTHON LEC\\Jan 24 ML Day 8\\tips.csv")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(pd.read_csv("C:\\Users\\Piyush Nayak\\OneDrive\\Desktop\\PYTHON\\Acmegrade\\PYTHON LEC\\Jan 24 ML Day 8\\tips.csv")
)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
os.chdir("C:\\Users\\Piyush Nayak\\OneDrive\\Desktop\\PYTHON\\Acmegrade\\PYTHON LEC\\Jan 24 ML Day 8")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Piyush Nayak\\OneDrive\\Desktop\\PYTHON\\Acmegrade\\PYTHON LEC\\Jan 24 ML Day 8'

# %%
pd.read_csv('DemographicData.csv')
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats=pd.read_csv('tips.csv')
stats
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
stats.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
stats.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
stats.tail(20)
# Out:
#      total_bill   Aid     sex smoker   day    time  size
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# ...

# %%
print(len(stats))
print(stats.columns)
# Out:
# 244
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# column rename can be done by
# stats.column=['Name','age','etc']
# for some specific column
print(stats.head())
print()
# inplace=true can change the main 
# stats.rename(columns= {'tip':'Aid'},inplace=True)
stat2=stats.rename(columns= {'tip':'Aid'})
print(stats.head())

print(stat2.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#    total_bill   Aid     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# ...

# %%
# for adding a new column
stats['happy']='YES'
stats
# Out:
#      total_bill   tip     sex smoker   day    time  size happy
# 0         16.99  1.01  Female     No   Sun  Dinner     2   YES
# 1         10.34  1.66    Male     No   Sun  Dinner     3   YES
# 2         21.01  3.50    Male     No   Sun  Dinner     3   YES
# 3         23.68  3.31    Male     No   Sun  Dinner     2   YES
# 4         24.59  3.61  Female     No   Sun  Dinner     4   YES
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   YES
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   YES
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   YES
# 242       17.82  1.75    Male     No   Sat  Dinner     2   YES
# 243       18.78  3.00  Female     No  Thur  Dinner     2   YES
#
# [244 rows x 8 columns]

# %%
p=stats[stats.tip < 2]
print(p)
print("length of p ",len(p))
# Out:
#      total_bill   tip     sex smoker   day    time  size happy
# 0         16.99  1.01  Female     No   Sun  Dinner     2   YES
# 1         10.34  1.66    Male     No   Sun  Dinner     3   YES
# 8         15.04  1.96    Male     No   Sun  Dinner     2   YES
# 10        10.27  1.71    Male     No   Sun  Dinner     2   YES
# 12        15.42  1.57    Male     No   Sun  Dinner     2   YES
# 16        10.33  1.67  Female     No   Sun  Dinner     3   YES
# 30         9.55  1.45    Male     No   Sat  Dinner     2   YES
# 43         9.68  1.32    Male     No   Sun  Dinner     2   YES
# 53         9.94  1.56    Male     No   Sun  Dinner     2   YES
# 57        26.41  1.50  Female     No   Sat  Dinner     2   YES
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2   YES
# 62        11.02  1.98    Male    Yes   Sat  Dinner     2   YES
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1   YES
# 70        12.02  1.97    Male     No   Sat  Dinner     2   YES
# ...

# %%
# now adding total payment customer will give
stats['Final_Bill']=stats['total_bill'] + stats['tip']
stats
# Out:
#      total_bill   tip     sex smoker   day    time  size happy  Final_Bill
# 0         16.99  1.01  Female     No   Sun  Dinner     2   YES       18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3   YES       12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3   YES       24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2   YES       26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4   YES       28.20
# ..          ...   ...     ...    ...   ...     ...   ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   YES       34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   YES       29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   YES       24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2   YES       19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2   YES       21.78
#
# [244 rows x 9 columns]

# %%
# stats['happy'][5]='NO'
stats.loc[5, 'happy'] = 'NO'

print(stats.iloc[[5]])
# Out:
#    total_bill   tip   sex smoker  day    time  size happy  Final_Bill
# 5       25.29  4.71  Male     No  Sun  Dinner     4    NO        30.0

# %%
stats= pd.read_csv('DemographicData.csv')
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats[stats['Country Name'].str.contains('ye',case=False)]
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 190  Yemen, Rep.          YEM      32.947            20.0  Lower middle income

# %%
stats[stats['Country Name'].str.contains('af',case=False)]
# Out:
#                  Country Name Country Code  Birth rate  Internet users  \
# 1                 Afghanistan          AFG      35.253             5.9
# 29   Central African Republic          CAF      34.076             3.5
# 191              South Africa          ZAF      20.850            46.5
#
#             Income Group
# 1             Low income
# 29            Low income
# 191  Upper middle income

# %%
stats[stats['Country Name'].str.contains('af',case=False,na=False)]
# Out:
#                  Country Name Country Code  Birth rate  Internet users  \
# 1                 Afghanistan          AFG      35.253             5.9
# 29   Central African Republic          CAF      34.076             3.5
# 191              South Africa          ZAF      20.850            46.5
#
#             Income Group
# 1             Low income
# 29            Low income
# 191  Upper middle income

# %%
stats[stats['Country Name'].str.contains('Af')]
# Out:
#                  Country Name Country Code  Birth rate  Internet users  \
# 1                 Afghanistan          AFG      35.253             5.9
# 29   Central African Republic          CAF      34.076             3.5
# 191              South Africa          ZAF      20.850            46.5
#
#             Income Group
# 1             Low income
# 29            Low income
# 191  Upper middle income

# %%
# stats.rename(Income Group, I_grp)
stats.rename(columns={'Income Group' : 'I_grp'},inplace=True)
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#                    I_grp
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats.I_grp.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
#in this only low comtains
p=stats[stats['I_grp'].str.contains('low ',case=False)]
# but in this lower also get contained
q=stats[stats['I_grp'].str.contains('low',case=False)]
print(q)
print()
# print(q.len())
print()
print(p)
# print(p.len)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 1         Afghanistan          AFG      35.253             5.9
# 6             Armenia          ARM      13.308            41.9
# 11            Burundi          BDI      44.151             1.3
# 13              Benin          BEN      36.440             4.9
# 14       Burkina Faso          BFA      40.551             9.1
# ..                ...          ...         ...             ...
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#                    I_grp
# 1             Low income
# 6    Lower middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# ...

# %%
tips=pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[['tip','day']]
# Out:
#       tip   day
# 0    1.01   Sun
# 1    1.66   Sun
# 2    3.50   Sun
# 3    3.31   Sun
# 4    3.61   Sun
# ..    ...   ...
# 239  5.92   Sat
# 240  2.00   Sat
# 241  2.00   Sat
# 242  1.75   Sat
# 243  3.00  Thur
#
# [244 rows x 2 columns]

# %%
tips[tips.time.isna()]
# Out:
#     total_bill   tip   sex smoker  day time  size
# 13       18.43  3.00  Male     No  Sun  NaN     4
# 19       20.65  3.35  Male     No  Sat  NaN     3
# 23       39.42  7.58   NaN     No  Sat  NaN     4
# 26       13.37  2.00  Male     No  Sat  NaN     2

# %%
tips[tips.sex.isna()]
# Out:
#     total_bill   tip  sex smoker  day    time  size
# 20       17.92  4.08  NaN    NaN  Sat  Dinner     2
# 23       39.42  7.58  NaN     No  Sat     NaN     4
# 31       18.35  2.50  NaN     No  Sat  Dinner     4

# %%
tips[tips.day.isna()]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 7        26.88  3.12    Male     No  NaN  Dinner     4
# 11       35.26  5.00  Female     No  NaN  Dinner     4
# 18       16.97  3.50  Female     No  NaN  Dinner     3
# 25       17.81  2.34    Male     No  NaN  Dinner     4
# 32       15.06  3.00  Female     No  NaN  Dinner     2
# 40       16.04  2.24    Male     No  NaN  Dinner     3

# %%
tips[tips.smoker.isna()]
# Out:
#     total_bill   tip  sex smoker  day    time  size
# 20       17.92  4.08  NaN    NaN  Sat  Dinner     2

# %%
tips.groupby('smoker').size()
# Out:
# smoker
# No     150
# Yes     93
# dtype: int64

# %%
tips.groupby('smoker').size()

# %%
tips.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      154
# dtype: int64

# %%
tips.groupby('smoker').count()
# Out:
#         total_bill  tip  sex  day  time  size
# smoker
# No             150  150  148  144   146   150
# Yes             93   93   93   93    93    93

# %%
tips.groupby('tip').agg(sum)
# Out:
# C:\Users\Piyush Nayak\AppData\Local\Temp\ipykernel_18452\1524161401.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tips.groupby('tip').agg(sum)
#        total_bill                     sex       smoker           day  \
# tip
# 1.00        28.67  FemaleFemaleFemaleMale  YesYesNoYes  SatFriSatSat
# 1.01        16.99                  Female           No           Sun
# 1.10        12.90                  Female          Yes           Sat
# 1.17        32.83                    Male          Yes           Sat
# 1.25        29.09          MaleFemaleMale       NoNoNo    SatThurSat
# ...           ...                     ...          ...           ...
# 6.70        34.30                    Male           No          Thur
# 6.73        48.27                    Male           No           Sat
# ...

# %%
tips.groupby('sex').agg({'tip' : 'sum'})
# Out:
#            tip
# sex
# Female  246.51
# Male    470.91

# %%
tips.groupby('sex').agg({'tip' : 'mean'})
# Out:
#              tip
# sex
# Female  2.833448
# Male    3.057857

# %%
tips.groupby('day').agg({'tip' : 'sum'})
# Out:
#          tip
# day
# Fri    51.96
# Sat   252.82
# Sun   235.77
# Thur  171.83

# %%
tips.groupby('day').agg({'tip' : 'mean'})
# Out:
#            tip
# day
# Fri   2.734737
# Sat   3.009762
# Sun   3.229726
# Thur  2.771452

# %%
# tips.groupby('day').agg({'tip': np.sum})

# %%
tips.groupby('time').agg({'tip':'sum','sex':'sum'})
# Out:
#            tip                                                sex
# time
# Dinner  530.14  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# Lunch   185.51  MaleMaleMaleMaleMaleFemaleMaleMaleFemaleMaleMa...

# %%
tips.groupby('time').agg({'tip':'sum','sex':'count'})
# Out:
#            tip  sex
# time
# Dinner  530.14  170
# Lunch   185.51   68

# %%
tips.groupby('time').agg({'tip':'mean','sex':'count'})
# Out:
#              tip  sex
# time
# Dinner  3.082209  170
# Lunch   2.728088   68

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby(['day','time']).agg({'tip' : ['sum','mean']})
# Out:
#                 tip
#                 sum      mean
# day  time
# Fri  Dinner   35.28  2.940000
#      Lunch    16.68  2.382857
# Sat  Dinner  239.89  2.961605
# Sun  Dinner  232.77  3.232917
# Thur Dinner    3.00  3.000000
#      Lunch   168.83  2.767705

# %%
tips.groupby(['day','time']).agg({'tip' : ['sum','mean','min','max']})
# Out:
#                 tip
#                 sum      mean   min    max
# day  time
# Fri  Dinner   35.28  2.940000  1.00   4.73
#      Lunch    16.68  2.382857  1.58   3.48
# Sat  Dinner  239.89  2.961605  1.00  10.00
# Sun  Dinner  232.77  3.232917  1.01   6.50
# Thur Dinner    3.00  3.000000  3.00   3.00
#      Lunch   168.83  2.767705  1.25   6.70

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips[tips['day'].str.contains('Sun',case=False,na=True)]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [79 rows x 7 columns]

# %%
tips[tips['day'].str.contains('Thur',case=False,na=False)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [62 rows x 7 columns]

# %%
tips.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           84   84   81      83    81    84
# Sun           73   73   73      73    72    73
# Thur          62   62   62      62    62    62

# %%
tips.groupby('day').size()
# Out:
# day
# Fri     19
# Sat     84
# Sun     73
# Thur    62
# dtype: int64

# %%
print(tips)
tips.drop(242,inplace=True)
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# ...

# %%
sorted_df=tips.sort_values(by = ['sex'])
sorted_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 139       13.16  2.75  Female     No  Thur   Lunch     2
# 137       14.15  2.00  Female     No  Thur   Lunch     2
# 136       10.33  2.00  Female     No  Thur   Lunch     2
# 135        8.51  1.25  Female     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 122       14.26  2.50    Male     No  Thur   Lunch     2
# 20        17.92  4.08     NaN    NaN   Sat  Dinner     2
# 23        39.42  7.58     NaN     No   Sat     NaN     4
# 31        18.35  2.50     NaN     No   Sat  Dinner     4
#
# [243 rows x 7 columns]

# %%
tips= pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.groupby('day').agg({ 'tip' : ['sum','max'] , 'smoker' : ['count']  })
# Out:
#          tip        smoker
#          sum    max  count
# day
# Fri    51.96   4.73     19
# Sat   252.82  10.00     83
# Sun   235.77   6.50     73
# Thur  171.83   6.70     62

# %%
tips[tips['day']=='Thur'].index
# Out:
# Index([ 77,  78,  79,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89, 117,
#        118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131,
#        132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145,
#        146, 147, 148, 149, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200,
#        201, 202, 203, 204, 205, 243],
#       dtype='int64')

# %%
# now we get the index we can use drop to get it drop

# %%
df1=pd.read_csv('tips.csv')
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1=df1.drop(tips[tips['day']=='Thur'].index)
df1
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [182 rows x 7 columns]

# %%
df1[df1['day']=='Sun']
df1[df1['day']=='Sat']
df1[df1['day']=='Thur']
df1.groupby('day').count()
# Out:
#      total_bill  tip  sex  smoker  time  size
# day
# Fri          19   19   19      19    19    19
# Sat          84   84   81      83    81    84
# Sun          73   73   73      73    72    73

# %%
tips.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           84   84   81      83    81    84
# Sun           73   73   73      73    72    73
# Thur          62   62   62      62    62    62
