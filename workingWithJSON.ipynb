# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d rtatman/iris-dataset-json-version
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/rtatman/iris-dataset-json-version
# License(s): unknown
# iris-dataset-json-version.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('iris-dataset-json-version.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close
# Out:
# <bound method ZipFile.close of <zipfile.ZipFile filename='iris-dataset-json-version.zip' mode='r'>>

# %%
import pandas as pd
df = pd.read_json('/content/iris.json')
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]
