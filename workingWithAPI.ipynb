# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/157336/videos?api_key=2ea4e4b4343a8c2460bd52e3ef8069ee')

# %%
df=pd.DataFrame( response.json()['results'])

# %%
df.head()
# Out:
#   iso_639_1 iso_3166_1                                      name          key  \
# 0        en         US  Behind The Scenes vs. Actual Movie Scene  MCsG9zH7DJE
# 1        en         US        Murph Saves The World - Full Scene  Rvns5DaW-ug
# 2        en         US                             Docking Scene  v2H1s9gj5DA
# 3        en         US                   “Tidal Wave" Full Scene  60h6lpnSgck
# 4        en         US                         Interstellar Live  IIFd8NPCj-E
#
#       site  size               type  official              published_at  \
# 0  YouTube  1080  Behind the Scenes      True  2024-03-17T12:59:46.000Z
# 1  YouTube  1080               Clip      True  2024-03-16T12:59:46.000Z
# 2  YouTube  1080               Clip      True  2024-03-03T13:59:55.000Z
# 3  YouTube  1080               Clip      True  2024-02-24T13:59:53.000Z
# 4  YouTube  1080         Featurette      True  2015-03-31T13:16:18.000Z
#
#                          id
# 0  65fa45831a3248017d76aec0
# ...

# %%
df1 = df[['name','key','size','site','type']]
df1
# Out:
#                                                  name          key  size  \
# 0            Behind The Scenes vs. Actual Movie Scene  MCsG9zH7DJE  1080
# 1                  Murph Saves The World - Full Scene  Rvns5DaW-ug  1080
# 2                                       Docking Scene  v2H1s9gj5DA  1080
# 3                             “Tidal Wave" Full Scene  60h6lpnSgck  1080
# 4                                   Interstellar Live  IIFd8NPCj-E  1080
# 5   Beyond The World of Interstellar - A special o...  PG5c2GgkA2w  1080
# 6             Own it TODAY on Blu-ray and DIGITAL HD!  KlyknsTJk0w   720
# 7   "Interstellar" winning the Oscar® for Visual E...  w7JZCsSD92E   720
# 8   BAFTA 2015 Special Visual Effects Winner | Bac...  _F5cmjqt5I8  1080
# 9         AFI AWARDS 2014 Video Almanac: INTERSTELLAR  dz_928ZO19Y  1080
# 10                                     Now Playing #3  Y9rdngQZfUU  1080
# 11                              Now Playing (Critics)  XsCfS5besfo  1080
# ...

# %%
import requests

url = "https://vanitysoft-boundaries-io-v1.p.rapidapi.com/rest/v1/public/boundary/censustract/within"

querystring = {"latitude":"37.5053796","longitude":"-77.5550683"}

headers = {
    "x-rapidapi-key": "cde0f1499bmsh018ecc5389fc138p17fc6fjsn3ba46666d65d",
    "x-rapidapi-host": "vanitysoft-boundaries-io-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print("Status Code:", response.status_code)
print("Response Headers:", response.headers)
print("Response Text:", response.text)
# Out:
# Status Code: 403
# Response Headers: {'Date': 'Tue, 16 Jul 2024 13:46:26 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-RapidAPI-Version': '1.2.8', 'X-RapidAPI-Region': 'AWS - us-east-1', 'X-RapidAPI-Proxy-Response': 'true', 'Server': 'RapidAPI-1.2.8'}
# Response Text: {"message":"You are not subscribed to this API."}

# %%
import requests

url = "https://movie-database-alternative.p.rapidapi.com/"

querystring = {"s":"Avengers Endgame","r":"json","page":"1"}

headers = {
	"x-rapidapi-key": "cde0f1499bmsh018ecc5389fc138p17fc6fjsn3ba46666d65d",
	"x-rapidapi-host": "movie-database-alternative.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'message': 'You are not subscribed to this API.'}
